# %%
# %pip install xgboost

# %%
# Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import learning_curve
from sklearn.metrics import RocCurveDisplay, PrecisionRecallDisplay
from sklearn.metrics import roc_auc_score, average_precision_score, classification_report

# %%
# Loading the data

df_train = pd.read_csv('../Data/train.csv')
df_test = pd.read_csv('../Data/test.csv')   

# Add a new column 'Transported' to the test dataset and set it to False

df_test['Transported'] = False

# %%
# Concatenate the train and test datasets

df = pd.concat([df_train, df_test], sort = False)

# And checking if the number of rows in the concatenated dataset is equal to the sum of the rows in the train and test datasets

df.shape[0] == df_train.shape[0] + df_test.shape[0]
# Out:
# True

# %%
# I. Before applying Machine Learning, let's ensure the data is clean and ready for modeling

# First let's look at the first 4 rows of the dataset

print(df.head(4).T)
# Out:
#                             0             1              2             3
# PassengerId           0001_01       0002_01        0003_01       0003_02
# HomePlanet             Europa         Earth         Europa        Europa
# CryoSleep               False         False          False         False
# Cabin                   B/0/P         F/0/S          A/0/S         A/0/S
# Destination       TRAPPIST-1e   TRAPPIST-1e    TRAPPIST-1e   TRAPPIST-1e
# Age                      39.0          24.0           58.0          33.0
# VIP                     False         False           True         False
# RoomService               0.0         109.0           43.0           0.0
# FoodCourt                 0.0           9.0         3576.0        1283.0
# ShoppingMall              0.0          25.0            0.0         371.0
# Spa                       0.0         549.0         6715.0        3329.0
# VRDeck                    0.0          44.0           49.0         193.0
# Name          Maham Ofracculy  Juanna Vines  Altark Susent  Solam Susent
# Transported             False          True          False         False

# %%
# Check the basic information about the dataset

print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# Index: 12970 entries, 0 to 4276
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   12970 non-null  str
#  1   HomePlanet    12682 non-null  str
#  2   CryoSleep     12660 non-null  object
#  3   Cabin         12671 non-null  str
#  4   Destination   12696 non-null  str
#  5   Age           12700 non-null  float64
#  6   VIP           12674 non-null  object
#  7   RoomService   12707 non-null  float64
#  8   FoodCourt     12681 non-null  float64
#  9   ShoppingMall  12664 non-null  float64
#  10  Spa           12686 non-null  float64
#  11  VRDeck        12702 non-null  float64
#  12  Name          12676 non-null  str
#  13  Transported   12970 non-null  bool
# dtypes: bool(1), float64(6), object(2), str(5)
# memory usage: 1.9+ MB
# None

# %%
# Check for basic statistics

print(df.describe().T)
# Out:
#                 count        mean          std  min   25%   50%   75%      max
# Age           12700.0   28.771969    14.387261  0.0  19.0  27.0  38.0     79.0
# RoomService   12707.0  222.897852   647.596664  0.0   0.0   0.0  49.0  14327.0
# FoodCourt     12681.0  451.961675  1584.370747  0.0   0.0   0.0  77.0  29813.0
# ShoppingMall  12664.0  174.906033   590.558690  0.0   0.0   0.0  29.0  23492.0
# Spa           12686.0  308.476904  1130.279641  0.0   0.0   0.0  57.0  22408.0
# VRDeck        12702.0  306.789482  1180.097223  0.0   0.0   0.0  42.0  24133.0

# %%
# Check for missing values in the dataset
print(df.isnull().sum())
# Out:
# PassengerId       0
# HomePlanet      288
# CryoSleep       310
# Cabin           299
# Destination     274
# Age             270
# VIP             296
# RoomService     263
# FoodCourt       289
# ShoppingMall    306
# Spa             284
# VRDeck          268
# Name            294
# Transported       0
# dtype: int64

# %%
# II. Now that we are aware of some imperfections in out dataset, we have to proceed with some Feature Engineering

# Separation of the column Cabin in 3 news colums

df[['Deck', 'Num', 'Side']] = df['Cabin'].str.split('/', expand=True)

# Group info from PassengerId, before we drop it

df['Group'] = df['PassengerId'].str.split('_').str[0]
grp_size = df.groupby('Group')['PassengerId'].transform('count')
df['GroupSize'] = grp_size
df['IsAlone'] = (grp_size == 1).astype(int)

hp_lookup = df.dropna(subset=['HomePlanet']).groupby('Group')['HomePlanet'].first()
missing_hp = df['HomePlanet'].isna()
df.loc[missing_hp, 'HomePlanet'] = df.loc[missing_hp, 'Group'].map(hp_lookup)

# Creation of df1 where we delete Cabin, Name, PassengerId and Group because they are not relevant for the ML

df1 = df.drop(columns=['Cabin', 'Name', 'PassengerId', 'Group'])

# Verification

print(df1.head(4).T)
print()
print(df1.isnull().sum())
# Out:
#                         0            1            2            3
# HomePlanet         Europa        Earth       Europa       Europa
# CryoSleep           False        False        False        False
# Destination   TRAPPIST-1e  TRAPPIST-1e  TRAPPIST-1e  TRAPPIST-1e
# Age                  39.0         24.0         58.0         33.0
# VIP                 False        False         True        False
# RoomService           0.0        109.0         43.0          0.0
# FoodCourt             0.0          9.0       3576.0       1283.0
# ShoppingMall          0.0         25.0          0.0        371.0
# Spa                   0.0        549.0       6715.0       3329.0
# VRDeck                0.0         44.0         49.0        193.0
# Transported         False         True        False        False
# Deck                    B            F            A            A
# Num                     0            0            0            0
# Side                    P            S            S            S
# GroupSize               1            1            2            2
# IsAlone                 1            1            0            0
#
# HomePlanet      157
# CryoSleep       310
# Destination     274
# Age             270
# VIP             296
# RoomService     263
# FoodCourt       289
# ShoppingMall    306
# Spa             284
# VRDeck          268
# Transported       0
# Deck            299
# Num             299
# Side            299
# GroupSize         0
# IsAlone           0
# dtype: int64

# %%
# Let's give Deck and Side an U and -1 for Num when they are Unknown

df1['Deck'] = df1['Deck'].fillna('U')
df1['Num'] = df1['Num'].fillna(-1)
df1['Side'] = df1['Side'].fillna('U')

df1['Num'] = df1['Num'].astype(int)

print(df1.isnull().sum())
# Out:
# HomePlanet      157
# CryoSleep       310
# Destination     274
# Age             270
# VIP             296
# RoomService     263
# FoodCourt       289
# ShoppingMall    306
# Spa             284
# VRDeck          268
# Transported       0
# Deck              0
# Num               0
# Side              0
# GroupSize         0
# IsAlone           0
# dtype: int64

# %%
# Checking on how Deck and Side are assigned

print(df1['Deck'].value_counts())
print( )
print(df1['Side'].value_counts())
# Out:
# Deck
# F    4239
# G    3781
# E    1323
# B    1141
# C    1102
# D     720
# A     354
# U     299
# T      11
# Name: count, dtype: int64
#
# Side
# S    6381
# P    6290
# U     299
# Name: count, dtype: int64

# %%
# Let's map Deck and Side to ordinal values based on assumed cabin hierarchy. Unknowns (U) are isolated.

df1['Deck'] = df1['Deck'].map({'F': 0, 'G': 1, 'E': 2, 'B': 3, 'C': 4, 'D': 5, 'A': 6, 'U': 7, 'T': 8})
df1['Side'] = df1['Side'].map({'S': 2, 'P': 1, 'U': -1})

# %%
# Focusing on some possible inconsistency 

expenses = ['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']

print("Avant :")
print("NaN CryoSleep :", df1['CryoSleep'].isna().sum())
print(df1[expenses].isna().sum())

# CryoSleep == True  ->  expenses has to be 0

cryo_true = df1['CryoSleep'] == True
df1.loc[cryo_true, expenses] = df1.loc[cryo_true, expenses].fillna(0)

# expenses > 0  ->  CryoSleep has to be False

total_expenses = df1[expenses].sum(axis=1, skipna=True, min_count=1)
a_depense = (df1['CryoSleep'].isna()) & (total_expenses > 0)
df1.loc[a_depense, 'CryoSleep'] = False

print("\nAprès :")
print("NaN CryoSleep :", df1['CryoSleep'].isna().sum())
print(df1.isna().sum())
# Out:
# Avant :
# NaN CryoSleep : 310
# RoomService     263
# FoodCourt       289
# ShoppingMall    306
# Spa             284
# VRDeck          268
# dtype: int64
#
# Après :
# NaN CryoSleep : 136
# HomePlanet      157
# CryoSleep       136
# Destination     274
# Age             270
# VIP             296
# RoomService     170
# FoodCourt       180
# ShoppingMall    175
# Spa             177
# VRDeck          177
# Transported       0
# Deck              0
# Num               0
# Side              0
# GroupSize         0
# IsAlone           0
# dtype: int64

# %%
# Standarification of the other values with TCL / Z-score for the inter and floats values

cols_to_impute = ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']

means = df1[cols_to_impute].mean()
stds = df1[cols_to_impute].std()

df_scaled = (df1[cols_to_impute] - means) / stds

# KNNImputer on the standarized values

imputer = KNNImputer(n_neighbors=5)
imputed_scaled = imputer.fit_transform(df_scaled)

# Back to the original scale

df1[cols_to_impute] = imputed_scaled * stds.values + means.values

print(df1.head(4).T)
print()
print('Après les changements pour les ints et floats')
print(df1.isna().sum())
# Out:
#                         0            1            2            3
# HomePlanet         Europa        Earth       Europa       Europa
# CryoSleep           False        False        False        False
# Destination   TRAPPIST-1e  TRAPPIST-1e  TRAPPIST-1e  TRAPPIST-1e
# Age                  39.0         24.0         58.0         33.0
# VIP                 False        False         True        False
# RoomService           0.0        109.0         43.0          0.0
# FoodCourt             0.0          9.0       3576.0       1283.0
# ShoppingMall         -0.0         25.0         -0.0        371.0
# Spa                   0.0        549.0       6715.0       3329.0
# VRDeck                0.0         44.0         49.0        193.0
# Transported         False         True        False        False
# Deck                    3            0            6            6
# Num                     0            0            0            0
# Side                    1            2            2            2
# GroupSize               1            1            2            2
# IsAlone                 1            1            0            0
#
# Après les changements pour les ints et floats
# HomePlanet      157
# CryoSleep       136
# Destination     274
# Age               0
# VIP             296
# RoomService       0
# FoodCourt         0
# ShoppingMall      0
# Spa               0
# VRDeck            0
# Transported       0
# Deck              0
# Num               0
# Side              0
# GroupSize         0
# IsAlone           0
# dtype: int64

# %%
# For the str i use the most common value to populate it

df1['HomePlanet'] = df1['HomePlanet'].fillna(df1['HomePlanet'].mode()[0])
df1['Destination'] = df1['Destination'].fillna(df1['Destination'].mode()[0])

# Followed by a one-shot encoding

df1 = pd.get_dummies(df1, columns=['HomePlanet', 'Destination'])

for col in df1.select_dtypes(include=['bool']).columns:
    df1[col] = df1[col].astype(int)

print(df1.head(4).T)
print()
print('Après les changements pour les strings')
print(df1.isna().sum())
# Out:
#                                0      1       2       3
# CryoSleep                  False  False   False   False
# Age                         39.0   24.0    58.0    33.0
# VIP                        False  False    True   False
# RoomService                  0.0  109.0    43.0     0.0
# FoodCourt                    0.0    9.0  3576.0  1283.0
# ShoppingMall                -0.0   25.0    -0.0   371.0
# Spa                          0.0  549.0  6715.0  3329.0
# VRDeck                       0.0   44.0    49.0   193.0
# Transported                    0      1       0       0
# Deck                           3      0       6       6
# Num                            0      0       0       0
# Side                           1      2       2       2
# GroupSize                      1      1       2       2
# IsAlone                        1      1       0       0
# HomePlanet_Earth               0      1       0       0
# HomePlanet_Europa              1      0       1       1
# HomePlanet_Mars                0      0       0       0
# Destination_55 Cancri e        0      0       0       0
# Destination_PSO J318.5-22      0      0       0       0
# Destination_TRAPPIST-1e        1      1       1       1
#
# Après les changements pour les strings
# CryoSleep                    136
# Age                            0
# VIP                          296
# RoomService                    0
# FoodCourt                      0
# ShoppingMall                   0
# Spa                            0
# VRDeck                         0
# Transported                    0
# Deck                           0
# Num                            0
# Side                           0
# GroupSize                      0
# IsAlone                        0
# HomePlanet_Earth               0
# HomePlanet_Europa              0
# HomePlanet_Mars                0
# Destination_55 Cancri e        0
# Destination_PSO J318.5-22      0
# Destination_TRAPPIST-1e        0
# dtype: int64

# %%
# Finally for the bolleans, we also populate with the most popular

df1['VIP'] = df1['VIP'].fillna(df1['VIP'].mode()[0])
df1['CryoSleep'] = df1['CryoSleep'].fillna(df1['CryoSleep'].mode()[0])

# Changing the bolean values into ones and zeros

df1['Transported'] = df1['Transported'].astype(int)
df1['VIP'] = df1['VIP'].astype(int)
df1['CryoSleep'] = df1['CryoSleep'].astype(int)

print(df1.head(4).T)
print()
print('Après les changements pour les boleans')
print(df1.isna().sum())
# Out:
#                                       0      1             2       3
# CryoSleep                  0.000000e+00    0.0  0.000000e+00     0.0
# Age                        3.900000e+01   24.0  5.800000e+01    33.0
# VIP                        0.000000e+00    0.0  1.000000e+00     0.0
# RoomService                0.000000e+00  109.0  4.300000e+01     0.0
# FoodCourt                  5.684342e-14    9.0  3.576000e+03  1283.0
# ShoppingMall              -2.842171e-14   25.0 -2.842171e-14   371.0
# Spa                        0.000000e+00  549.0  6.715000e+03  3329.0
# VRDeck                     0.000000e+00   44.0  4.900000e+01   193.0
# Transported                0.000000e+00    1.0  0.000000e+00     0.0
# Deck                       3.000000e+00    0.0  6.000000e+00     6.0
# Num                        0.000000e+00    0.0  0.000000e+00     0.0
# Side                       1.000000e+00    2.0  2.000000e+00     2.0
# GroupSize                  1.000000e+00    1.0  2.000000e+00     2.0
# IsAlone                    1.000000e+00    1.0  0.000000e+00     0.0
# HomePlanet_Earth           0.000000e+00    1.0  0.000000e+00     0.0
# HomePlanet_Europa          1.000000e+00    0.0  1.000000e+00     1.0
# HomePlanet_Mars            0.000000e+00    0.0  0.000000e+00     0.0
# Destination_55 Cancri e    0.000000e+00    0.0  0.000000e+00     0.0
# Destination_PSO J318.5-22  0.000000e+00    0.0  0.000000e+00     0.0
# Destination_TRAPPIST-1e    1.000000e+00    1.0  1.000000e+00     1.0
#
# Après les changements pour les boleans
# CryoSleep                    0
# Age                          0
# VIP                          0
# RoomService                  0
# FoodCourt                    0
# ShoppingMall                 0
# Spa                          0
# VRDeck                       0
# Transported                  0
# Deck                         0
# Num                          0
# Side                         0
# GroupSize                    0
# IsAlone                      0
# HomePlanet_Earth             0
# HomePlanet_Europa            0
# HomePlanet_Mars              0
# Destination_55 Cancri e      0
# Destination_PSO J318.5-22    0
# Destination_TRAPPIST-1e      0
# dtype: int64

# %%
# III. We are done with the Feature Engineering we can now focus on the Model Training part

#  We use the df_train to have the dimension suggested by the kaggle and we split df1 again to separate it into new train and test dataset

train_len = df_train.shape[0]

df_train_clean = df1.iloc[:train_len].copy()
df_test_clean = df1.iloc[train_len:].copy()

print(len(df_train_clean))
print(len(df_test_clean))
# Out:
# 8693
# 4277

# %%
# After quite some tries I came to the conclusion that those features are not relevant for the model

features_to_drop = [
    'IsAlone',
    'Transported' # have to be removed
]

# We assign to x all the values we will use to predict y, which in our case corresponds to Transported

x = df_train_clean.drop(columns=features_to_drop)

y = df_train_clean['Transported']

# We also remove Transported from the test dataset itself, for the same reason we removed it from the training dataset

x_final = df_test_clean.drop(columns=features_to_drop)

# %%
# Let's try to find the best hyperparameters

parametres_a_tester = {
    'n_estimators': [300, 600, 900, 1200, 1500],  
    'max_depth': [3, 4, 5],           
    'learning_rate': [0.005, 0.01, 0.05], 
    'subsample': [0.6, 0.8, 1.0] # testing by different % of the passagers in each branch
}

modele_de_base = XGBClassifier(random_state=42, eval_metric='logloss')

# Search tool for testing desired values

recherche = GridSearchCV(
    estimator=modele_de_base, 
    param_grid=parametres_a_tester, 
    cv=5,        
    n_jobs=-1,   
    verbose=2    
)

print("L'ordinateur entraîne plusieurs modèles...")
recherche.fit(x, y)

print("Recherche terminée, les meilleurs paramètres sont :", recherche.best_params_)
print("Précision théorique estimée :", round(recherche.best_score_ * 100, 2), "%")
# Out:
# L'ordinateur entraîne plusieurs modèles...
# Fitting 5 folds for each of 135 candidates, totalling 675 fits
# Recherche terminée, les meilleurs paramètres sont : {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 900, 'subsample': 0.6}
# Précision théorique estimée : 79.85 %

# %%
final_predictions = recherche.predict(x_final)

# %%
submission3 = pd.DataFrame({
    'PassengerId': df_test['PassengerId'],
    'Transported': final_predictions.astype(bool) # Kaggle demands True / False
    })

# Save of the dataset

submission3.to_csv('../Submissions/submission_03_xgb.csv', index=False)
print("Fichier submission_03_xgb.csv généré avec succès")
# Out:
# Fichier submission_03_xgb.csv généré avec succès

# %%
# Extract the best model found by GridSearchCV

best_xgb_model = recherche.best_estimator_

# Calculate scores for different dataset sizes (from 10% to 100%)
train_sizes, train_scores, test_scores = learning_curve(
    estimator=best_xgb_model, 
    X=x, 
    y=y, 
    cv=5, 
    n_jobs=-1,
    train_sizes=np.linspace(0.1, 1.0, 10),
    scoring='accuracy'
)

# Calculate means and standard deviations
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Plotting the learning curve
plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, label="Training Score", color="blue", marker="o")
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="blue", alpha=0.1)
plt.plot(train_sizes, test_mean, label="Cross-Validation Score", color="purple", marker="s")
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="purple", alpha=0.1)

plt.title("Learning Curve - XGBoost")
plt.xlabel("Number of Training Passengers")
plt.ylabel("Accuracy")
plt.legend(loc="lower right")
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
# Extract feature importances

importances = best_xgb_model.feature_importances_
feature_names = x.columns

# Create a DataFrame for easy sorting

df_importances = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
df_importances = df_importances.sort_values(by='Importance', ascending=False)

# Plotting the feature importances 

plt.figure(figsize=(12, 8))
sns.barplot(
    x='Importance', 
    y='Feature', 
    hue='Feature', 
    data=df_importances, 
    palette='viridis', 
    legend=False
)
plt.title("Feature Importance - XGBoost")
plt.xlabel("Importance Level")
plt.ylabel("Features")
plt.grid(True, axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# ROC Curve
roc_disp = RocCurveDisplay.from_estimator(best_model, x, y, ax=axes[0])
roc_disp.line_.set_color("purple")
axes[0].set_title("ROC Curve")
axes[0].grid(True, linestyle='--', alpha=0.7)

# Precision-Recall Curve
pr_disp = PrecisionRecallDisplay.from_estimator(best_model, x, y, ax=axes[1])
pr_disp.line_.set_color("blue")
axes[1].set_title("Precision-Recall Curve")
axes[1].grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
# Calculating Probabilities for the Positive Class 

y_probs = best_model.predict_proba(x)[:, 1]
y_preds = best_model.predict(x)

# AUC alculation

auc_roc = roc_auc_score(y, y_probs)
ap_score = average_precision_score(y, y_probs)

print(f"ROC-AUC Score : {auc_roc:.4f}")
print(f"Precision-Recall AP Score : {ap_score:.4f}")
print("\n--- Classification Report ---")
print(classification_report(y, y_preds))
